# %% [markdown]
# # Introduction
# This notebook explores the American flight data in Jan 2018.

# %% [markdown]
# # Set up Environment

# %%
import pandas as pd

# be able to view all columns of dataframes
pd.options.display.max_columns = None

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
data_folder = '../data/raw/training_data_2018/'
df = pd.read_csv(data_folder + 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2018_1.zip')

# %% [markdown]
# # Pre-process Data

# %%
df.head(3)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2018        1      1          27          6  2018-01-27                UA
# 1  2018        1      1          27          6  2018-01-27                UA
# 2  2018        1      1          27          6  2018-01-27                UA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 0                     19977                          UA      N26232
# 1                     19977                          UA      N477UA
# 2                     19977                          UA      N13720
#
#    Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                              369            11697             1169706
# 1                              368            14747             1474703
# 2                              367            11278             1127805
#
#    OriginCityMarketID Origin       OriginCityName OriginState  \
# 0               32467    FLL  Fort Lauderdale, FL          FL
# 1               30559    SEA          Seattle, WA          WA
# 2               30852    DCA       Washington, DC          VA
#
#    OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0               12         Florida         33          12266
# 1               53      Washington         93          14771
# 2               51        Virginia         38          12266
#
#    DestAirportSeqID  DestCityMarketID Dest       DestCityName DestState  \
# 0           1226603             31453  IAH        Houston, TX        TX
# 1           1477104             32457  SFO  San Francisco, CA        CA
# 2           1226603             31453  IAH        Houston, TX        TX
#
#    DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0             48         Texas       74         615    602.0     -13.0
# 1              6    California       91         618    614.0      -4.0
# 2             48         Texas       74         830    828.0      -2.0
#
#    DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0              0.0       0.0                  -1.0  0600-0659     19.0
# 1              0.0       0.0                  -1.0  0600-0659     16.0
# 2              0.0       0.0                  -1.0  0800-0859     17.0
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0      621.0     749.0     7.0         808    756.0     -12.0
# 1      630.0     808.0     5.0         831    813.0     -18.0
# 2      845.0    1055.0    13.0        1107   1108.0       1.0
#
#    ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0              0.0       0.0                -1.0  0800-0859        0.0
# 1              0.0       0.0                -2.0  0800-0859        0.0
# 2              1.0       0.0                 0.0  1100-1159        0.0
#
#   CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0              NaN       0.0           173.0              174.0    148.0
# 1              NaN       0.0           133.0              119.0     98.0
# 2              NaN       0.0           217.0              220.0    190.0
#
#    Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  \
# 0      1.0     966.0              4           NaN           NaN       NaN
# 1      1.0     679.0              3           NaN           NaN       NaN
# 2      1.0    1208.0              5           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay  FirstDepTime  TotalAddGTime  \
# 0            NaN                NaN           NaN            NaN
# 1            NaN                NaN           NaN            NaN
# 2            NaN                NaN           NaN            NaN
#
#    LongestAddGTime  DivAirportLandings  DivReachedDest  DivActualElapsedTime  \
# 0              NaN                   0             NaN                   NaN
# 1              NaN                   0             NaN                   NaN
# 2              NaN                   0             NaN                   NaN
#
#    DivArrDelay  DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  \
# 0          NaN          NaN         NaN            NaN               NaN
# 1          NaN          NaN         NaN            NaN               NaN
# 2          NaN          NaN         NaN            NaN               NaN
#
#    Div1WheelsOn  Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum  \
# 0           NaN             NaN               NaN            NaN         NaN
# 1           NaN             NaN               NaN            NaN         NaN
# 2           NaN             NaN               NaN            NaN         NaN
#
#   Div2Airport  Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0         NaN            NaN               NaN           NaN             NaN
# 1         NaN            NaN               NaN           NaN             NaN
# 2         NaN            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff Div2TailNum  Div3Airport  Div3AirportID  \
# 0               NaN            NaN         NaN          NaN            NaN
# 1               NaN            NaN         NaN          NaN            NaN
# 2               NaN            NaN         NaN          NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff  Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN          NaN          NaN            NaN               NaN
# 1            NaN          NaN          NaN            NaN               NaN
# 2            NaN          NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# 0               NaN            NaN          NaN           NaN
# 1               NaN            NaN          NaN           NaN
# 2               NaN            NaN          NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570118 entries, 0 to 570117
# Columns: 110 entries, Year to Unnamed: 109
# dtypes: float64(70), int64(21), object(19)
# memory usage: 478.5+ MB

# %%
num_cancelled_flights = df[df['Cancelled']==1]['Year'].count()
num_diverted_flights = df[df['Diverted']==1]['Year'].count()
print('Number of cancelled flights in Jan 2018: ', num_cancelled_flights)
print('Number of diverted flights in Jan 2018: ', num_diverted_flights)

total_rows = df.shape[0]
percentage = round((num_cancelled_flights+num_diverted_flights) / total_rows * 100,2)
print('Percentage of cancelled or diverted flights: ', percentage, '%')
# Out:
# Number of cancelled flights in Jan 2018:  17169
# Number of diverted flights in Jan 2018:  1249
# Percentage of cancelled or diverted flights:  3.23 %

# %%
not_cancelled = df['Cancelled']==0
not_diverted = df['Diverted']==0
normal_flights = not_cancelled & not_diverted

temp = df.copy()
flights = temp[normal_flights]

# %% [markdown]
# Next, drop columns related to cancellation or divertion and irrelevant column.

# %%
flights.head(3)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2018        1      1          27          6  2018-01-27                UA
# 1  2018        1      1          27          6  2018-01-27                UA
# 2  2018        1      1          27          6  2018-01-27                UA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 0                     19977                          UA      N26232
# 1                     19977                          UA      N477UA
# 2                     19977                          UA      N13720
#
#    Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                              369            11697             1169706
# 1                              368            14747             1474703
# 2                              367            11278             1127805
#
#    OriginCityMarketID Origin       OriginCityName OriginState  \
# 0               32467    FLL  Fort Lauderdale, FL          FL
# 1               30559    SEA          Seattle, WA          WA
# 2               30852    DCA       Washington, DC          VA
#
#    OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0               12         Florida         33          12266
# 1               53      Washington         93          14771
# 2               51        Virginia         38          12266
#
#    DestAirportSeqID  DestCityMarketID Dest       DestCityName DestState  \
# 0           1226603             31453  IAH        Houston, TX        TX
# 1           1477104             32457  SFO  San Francisco, CA        CA
# 2           1226603             31453  IAH        Houston, TX        TX
#
#    DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0             48         Texas       74         615    602.0     -13.0
# 1              6    California       91         618    614.0      -4.0
# 2             48         Texas       74         830    828.0      -2.0
#
#    DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0              0.0       0.0                  -1.0  0600-0659     19.0
# 1              0.0       0.0                  -1.0  0600-0659     16.0
# 2              0.0       0.0                  -1.0  0800-0859     17.0
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0      621.0     749.0     7.0         808    756.0     -12.0
# 1      630.0     808.0     5.0         831    813.0     -18.0
# 2      845.0    1055.0    13.0        1107   1108.0       1.0
#
#    ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0              0.0       0.0                -1.0  0800-0859        0.0
# 1              0.0       0.0                -2.0  0800-0859        0.0
# 2              1.0       0.0                 0.0  1100-1159        0.0
#
#   CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0              NaN       0.0           173.0              174.0    148.0
# 1              NaN       0.0           133.0              119.0     98.0
# 2              NaN       0.0           217.0              220.0    190.0
#
#    Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  NASDelay  \
# 0      1.0     966.0              4           NaN           NaN       NaN
# 1      1.0     679.0              3           NaN           NaN       NaN
# 2      1.0    1208.0              5           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay  FirstDepTime  TotalAddGTime  \
# 0            NaN                NaN           NaN            NaN
# 1            NaN                NaN           NaN            NaN
# 2            NaN                NaN           NaN            NaN
#
#    LongestAddGTime  DivAirportLandings  DivReachedDest  DivActualElapsedTime  \
# 0              NaN                   0             NaN                   NaN
# 1              NaN                   0             NaN                   NaN
# 2              NaN                   0             NaN                   NaN
#
#    DivArrDelay  DivDistance Div1Airport  Div1AirportID  Div1AirportSeqID  \
# 0          NaN          NaN         NaN            NaN               NaN
# 1          NaN          NaN         NaN            NaN               NaN
# 2          NaN          NaN         NaN            NaN               NaN
#
#    Div1WheelsOn  Div1TotalGTime  Div1LongestGTime  Div1WheelsOff Div1TailNum  \
# 0           NaN             NaN               NaN            NaN         NaN
# 1           NaN             NaN               NaN            NaN         NaN
# 2           NaN             NaN               NaN            NaN         NaN
#
#   Div2Airport  Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0         NaN            NaN               NaN           NaN             NaN
# 1         NaN            NaN               NaN           NaN             NaN
# 2         NaN            NaN               NaN           NaN             NaN
#
#    Div2LongestGTime  Div2WheelsOff Div2TailNum  Div3Airport  Div3AirportID  \
# 0               NaN            NaN         NaN          NaN            NaN
# 1               NaN            NaN         NaN          NaN            NaN
# 2               NaN            NaN         NaN          NaN            NaN
#
#    Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  Div3LongestGTime  \
# 0               NaN           NaN             NaN               NaN
# 1               NaN           NaN             NaN               NaN
# 2               NaN           NaN             NaN               NaN
#
#    Div3WheelsOff  Div3TailNum  Div4Airport  Div4AirportID  Div4AirportSeqID  \
# 0            NaN          NaN          NaN            NaN               NaN
# 1            NaN          NaN          NaN            NaN               NaN
# 2            NaN          NaN          NaN            NaN               NaN
#
#    Div4WheelsOn  Div4TotalGTime  Div4LongestGTime  Div4WheelsOff  Div4TailNum  \
# 0           NaN             NaN               NaN            NaN          NaN
# 1           NaN             NaN               NaN            NaN          NaN
# 2           NaN             NaN               NaN            NaN          NaN
#
#    Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0          NaN            NaN               NaN           NaN             NaN
# 1          NaN            NaN               NaN           NaN             NaN
# 2          NaN            NaN               NaN           NaN             NaN
#
#    Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# 0               NaN            NaN          NaN           NaN
# 1               NaN            NaN          NaN           NaN
# 2               NaN            NaN          NaN           NaN

# %%
field_list = ['FirstDepTime', 'TotalAddGTime', 'LongestAddGTime', 'DivAirportLandings', 'DivReachedDest',\
              'DivActualElapsedTime', 'DivArrDelay', 'DivDistance', 'Div1Airport', 'Div1AirportID', 'Div1AirportSeqID',\
              'Div1WheelsOn', 'Div1TotalGTime', 'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum',  'Div2Airport', \
              'Div2AirportID', 'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 'Div2LongestGTime', 'Div2WheelsOff',\
              'Div2TailNum', 'Div3Airport', 'Div3AirportID', 'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime',\
              'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum', 'Div4Airport', 'Div4AirportID', 'Div4AirportSeqID', \
              'Div4WheelsOn', 'Div4TotalGTime', 'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', \
              'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 'Div5LongestGTime', \
              'Div5WheelsOff', 'Div5TailNum', 'Cancelled', 'CancellationCode', 'Diverted']

for field in field_list:
    flights = flights.drop(labels=field, axis=1)
    
flights.drop(flights.columns[flights.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)

# %%
flights.shape
# Out:
# (551700, 58)

# %% [markdown]
# Find the airport with the most arrival flights:

# %%
flights['DestAirportID'].value_counts(ascending=False).head(5)
# Out:
# 10397    29709
# 13930    24997
# 11298    21754
# 11292    17980
# 12892    17545
# Name: DestAirportID, dtype: int64

# %%
flights[flights['DestAirportID']==10397]['Dest'].head(1)
# Out:
# 35    ATL
# Name: Dest, dtype: object

# %% [markdown]
# The most frequently visited airport has airport ID 10397, code being ATL. Find all flight traffic in ATL in Jan 2018:

# %%
arrivals = flights['DestAirportID']==10397
departures = flights['OriginAirportID']==10397
all_flights = arrivals | departures
flights_ATL = flights[all_flights]

# %%
flights_ATL.shape
# Out:
# (59401, 58)

# %%
flights_ATL.head(3)
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 35   2018        1      1          27          6  2018-01-27
# 58   2018        1      1          27          6  2018-01-27
# 112  2018        1      1          27          6  2018-01-27
#
#     Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 35                 UA                     19977                          UA
# 58                 UA                     19977                          UA
# 112                UA                     19977                          UA
#
#     Tail_Number  Flight_Number_Reporting_Airline  OriginAirportID  \
# 35       N68807                              333            12266
# 58       N816UA                              311            10397
# 112      N76502                              258            10397
#
#      OriginAirportSeqID  OriginCityMarketID Origin OriginCityName OriginState  \
# 35              1226603               31453    IAH    Houston, TX          TX
# 58              1039707               30397    ATL    Atlanta, GA          GA
# 112             1039707               30397    ATL    Atlanta, GA          GA
#
#      OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 35                48           Texas         74          10397
# 58                13         Georgia         34          13930
# 112               13         Georgia         34          12266
#
#      DestAirportSeqID  DestCityMarketID Dest DestCityName DestState  \
# 35            1039707             30397  ATL  Atlanta, GA        GA
# 58            1393006             30977  ORD  Chicago, IL        IL
# 112           1226603             31453  IAH  Houston, TX        TX
#
#      DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 35              13       Georgia       34         735    731.0      -4.0
# 58              17      Illinois       41         705    657.0      -8.0
# 112             48         Texas       74        1738   1730.0      -8.0
#
#      DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 35               0.0       0.0                  -1.0  0700-0759     17.0
# 58               0.0       0.0                  -1.0  0700-0759     13.0
# 112              0.0       0.0                  -1.0  1700-1759     11.0
#
#      WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 35       748.0    1023.0     8.0        1043   1031.0     -12.0
# 58       710.0     743.0     8.0         813    751.0     -22.0
# 112     1741.0    1838.0    13.0        1858   1851.0      -7.0
#
#      ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  CRSElapsedTime  \
# 35               0.0       0.0                -1.0  1000-1059           128.0
# 58               0.0       0.0                -2.0  0800-0859           128.0
# 112              0.0       0.0                -1.0  1800-1859           140.0
#
#      ActualElapsedTime  AirTime  Flights  Distance  DistanceGroup  \
# 35               120.0     95.0      1.0     689.0              3
# 58               114.0     93.0      1.0     606.0              3
# 112              141.0    117.0      1.0     689.0              3
#
#      CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 35            NaN           NaN       NaN            NaN                NaN
# 58            NaN           NaN       NaN            NaN                NaN
# 112           NaN           NaN       NaN            NaN                NaN

# %%
# split flights_ATL into two df: for arrival and departure flights respectively
atl_id = 10397
arrivals = flights_ATL[flights_ATL['DestAirportID']==atl_id]
departures = flights_ATL[flights_ATL['OriginAirportID']==atl_id]

# %% [markdown]
# For each arrival and departure flight, get its SLDT and STOT respectively. Timings will be in the format of date + time.

# %%
# convert FlightDate to a datetime object
arrivals['FlightDate'] = pd.to_datetime(arrivals['FlightDate'])
departures['FlightDate'] = pd.to_datetime(departures['FlightDate'])

# CRSArrTime is an int with max four digits. Append zeros to make all consist of 4 digits
# then convert to a datetime object
def format_time(CRSTime):
    time_str = str(CRSTime)
    formatted_time_str = time_str.zfill(4)
    time = pd.to_datetime(formatted_time_str, format="%H%M")
    return time

arrivals['CRSArrTime'] = arrivals['CRSArrTime'].apply(lambda x: format_time(x)).dt.time
departures['CRSDepTime'] = departures['CRSDepTime'].apply(lambda x: format_time(x)).dt.time

# for arrival flights, the flight date may not be equal to ARRIVAL date
# e.g., depart at origin airport at 2350 1 Jan, then arrived at ATL at 0340 2 Jan at ATL

# add a column called ArrivalDate in arrivals dataframe
# initialize the column values to be the same as FlightDate
arrivals['ArrivalDate'] = arrivals['FlightDate']

# for the arrival flights with CRSArrTime < CRSDepTime (convert CRSDepTime to a datetime object first)
# let ArrivalDate be FlightDate + 1
arrivals['CRSDepTime'] = arrivals['CRSDepTime'].apply(lambda x: format_time(x)).dt.time
one_day = pd.Timedelta('1 days')
arrivals.loc[arrivals.CRSArrTime < arrivals.CRSDepTime, "ArrivalDate"] = arrivals['FlightDate'] + one_day

# ARR_Flight_SLDT is obtained by concatenating ArrivalDate and CRSArrTime
arrivals['ARR_Flight_SLDT'] = arrivals.apply(lambda r: pd.datetime.combine(r['ArrivalDate'], r['CRSArrTime']), 1)

# concatenate departure date and time to generate STOT first
departures['DEP_Flight_STOT'] = departures.apply(lambda r: pd.datetime.combine(r['FlightDate'], r['CRSDepTime']), 1)

# %%
arrivals.head(3)
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 35   2018        1      1          27          6 2018-01-27                UA
# 132  2018        1      1          27          6 2018-01-27                UA
# 188  2018        1      1          26          5 2018-01-26                UA
#
#      DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 35                      19977                          UA      N68807
# 132                     19977                          UA      N14731
# 188                     19977                          UA      N401UA
#
#      Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 35                               333            12266             1226603
# 132                              241            11618             1161802
# 188                             2414            11618             1161802
#
#      OriginCityMarketID Origin OriginCityName OriginState  OriginStateFips  \
# 35                31453    IAH    Houston, TX          TX               48
# 132               31703    EWR     Newark, NJ          NJ               34
# 188               31703    EWR     Newark, NJ          NJ               34
#
#     OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 35            Texas         74          10397           1039707
# 132      New Jersey         21          10397           1039707
# 188      New Jersey         21          10397           1039707
#
#      DestCityMarketID Dest DestCityName DestState  DestStateFips  \
# 35              30397  ATL  Atlanta, GA        GA             13
# 132             30397  ATL  Atlanta, GA        GA             13
# 188             30397  ATL  Atlanta, GA        GA             13
#
#     DestStateName  DestWac CRSDepTime  DepTime  DepDelay  DepDelayMinutes  \
# 35        Georgia       34   07:35:00    731.0      -4.0              0.0
# 132       Georgia       34   06:05:00    559.0      -6.0              0.0
# 188       Georgia       34   11:18:00   1110.0      -8.0              0.0
#
#      DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 35        0.0                  -1.0  0700-0759     17.0      748.0    1023.0
# 132       0.0                  -1.0  0600-0659     13.0      612.0     808.0
# 188       0.0                  -1.0  1100-1159     12.0     1122.0    1315.0
#
#      TaxiIn CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 35      8.0   10:43:00   1031.0     -12.0              0.0       0.0
# 132    11.0   08:43:00    819.0     -24.0              0.0       0.0
# 188     8.0   13:51:00   1323.0     -28.0              0.0       0.0
#
#      ArrivalDelayGroups ArrTimeBlk  CRSElapsedTime  ActualElapsedTime  \
# 35                 -1.0  1000-1059           128.0              120.0
# 132                -2.0  0800-0859           158.0              140.0
# 188                -2.0  1300-1359           153.0              133.0
#
#      AirTime  Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 35      95.0      1.0     689.0              3           NaN           NaN
# 132    116.0      1.0     746.0              3           NaN           NaN
# 188    113.0      1.0     746.0              3           NaN           NaN
#
#      NASDelay  SecurityDelay  LateAircraftDelay ArrivalDate  \
# 35        NaN            NaN                NaN  2018-01-27
# 132       NaN            NaN                NaN  2018-01-27
# 188       NaN            NaN                NaN  2018-01-26
#
#         ARR_Flight_SLDT
# 35  2018-01-27 10:43:00
# 132 2018-01-27 08:43:00
# 188 2018-01-26 13:51:00

# %%
departures.head(3)
# Out:
#      Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate Reporting_Airline  \
# 58   2018        1      1          27          6 2018-01-27                UA
# 112  2018        1      1          27          6 2018-01-27                UA
# 125  2018        1      1          27          6 2018-01-27                UA
#
#      DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  \
# 58                      19977                          UA      N816UA
# 112                     19977                          UA      N76502
# 125                     19977                          UA      N68807
#
#      Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 58                               311            10397             1039707
# 112                              258            10397             1039707
# 125                              247            10397             1039707
#
#      OriginCityMarketID Origin OriginCityName OriginState  OriginStateFips  \
# 58                30397    ATL    Atlanta, GA          GA               13
# 112               30397    ATL    Atlanta, GA          GA               13
# 125               30397    ATL    Atlanta, GA          GA               13
#
#     OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 58          Georgia         34          13930           1393006
# 112         Georgia         34          12266           1226603
# 125         Georgia         34          11618           1161802
#
#      DestCityMarketID Dest DestCityName DestState  DestStateFips  \
# 58              30977  ORD  Chicago, IL        IL             17
# 112             31453  IAH  Houston, TX        TX             48
# 125             31703  EWR   Newark, NJ        NJ             34
#
#     DestStateName  DestWac CRSDepTime  DepTime  DepDelay  DepDelayMinutes  \
# 58       Illinois       41   07:05:00    657.0      -8.0              0.0
# 112         Texas       74   17:38:00   1730.0      -8.0              0.0
# 125    New Jersey       21   11:38:00   1129.0      -9.0              0.0
#
#      DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  WheelsOff  WheelsOn  \
# 58        0.0                  -1.0  0700-0759     13.0      710.0     743.0
# 112       0.0                  -1.0  1700-1759     11.0     1741.0    1838.0
# 125       0.0                  -1.0  1100-1159     15.0     1144.0    1323.0
#
#      TaxiIn  CRSArrTime  ArrTime  ArrDelay  ArrDelayMinutes  ArrDel15  \
# 58      8.0         813    751.0     -22.0              0.0       0.0
# 112    13.0        1858   1851.0      -7.0              0.0       0.0
# 125     6.0        1359   1329.0     -30.0              0.0       0.0
#
#      ArrivalDelayGroups ArrTimeBlk  CRSElapsedTime  ActualElapsedTime  \
# 58                 -2.0  0800-0859           128.0              114.0
# 112                -1.0  1800-1859           140.0              141.0
# 125                -2.0  1300-1359           141.0              120.0
#
#      AirTime  Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 58      93.0      1.0     606.0              3           NaN           NaN
# 112    117.0      1.0     689.0              3           NaN           NaN
# 125     99.0      1.0     746.0              3           NaN           NaN
#
#      NASDelay  SecurityDelay  LateAircraftDelay     DEP_Flight_STOT
# 58        NaN            NaN                NaN 2018-01-27 07:05:00
# 112       NaN            NaN                NaN 2018-01-27 17:38:00
# 125       NaN            NaN                NaN 2018-01-27 11:38:00

# %% [markdown]
# Create new features for arrival dataframe to represent airport congestion rate:\
# Number of flights arrived or departed within SLDT-30min and SLDT+30min, binned at 5min intervals.\
# Hence, the number of new features is (30+30)/5*2 = 24.\
# Column name example: Num_Arr_SLDT-30\
# i.e. Number of arrival flights in the interval of SLDT-30min and SLDT-25min at ATL airport.

# %%
# initialize new feature columns in arrivals df
feature_list = ['Num_Arr_SLDT-30', 'Num_Arr_SLDT-25', 'Num_Arr_SLDT-20', 'Num_Arr_SLDT-15', 'Num_Arr_SLDT-10',\
                'Num_Arr_SLDT-5', 'Num_Arr_SLDT-0', 'Num_Arr_SLDT+5', 'Num_Arr_SLDT+10', 'Num_Arr_SLDT+15',\
                'Num_Arr_SLDT+20', 'Num_Arr_SLDT+25', 'Num_Dep_SLDT-30', 'Num_Dep_SLDT-25', 'Num_Dep_SLDT-20',\
                'Num_Dep_SLDT-15', 'Num_Dep_SLDT-10', 'Num_Dep_SLDT-5', 'Num_Dep_SLDT-0', 'Num_Dep_SLDT+5',\
                'Num_Dep_SLDT+10', 'Num_Dep_SLDT+15', 'Num_Dep_SLDT+20', 'Num_Dep_SLDT+25']

for feature in feature_list:
    arrivals[feature] = 0

# %%
five_min = pd.Timedelta('5 minutes')
ten_min = pd.Timedelta('10 minutes')
fifteen_min = pd.Timedelta('15 minutes')
twenty_min = pd.Timedelta('20 minutes')
twenty5_min = pd.Timedelta('25 minutes')
thirty_min = pd.Timedelta('30 minutes')

# %%
# generate the dep STOT df
dep_flight_STOT = departures[['FlightDate','DEP_Flight_STOT']]

# generate the stot series
stot = dep_flight_STOT['DEP_Flight_STOT']

# generate the arr SLDT df
arr_flight_SLDT = arrivals[['FlightDate','ARR_Flight_SLDT']]

# generate the stot series
sldt = arr_flight_SLDT['ARR_Flight_SLDT']

# %%
features = ['Num_Dep_SLDT-30', 'Num_Dep_SLDT-25', 'Num_Dep_SLDT-20',\
            'Num_Dep_SLDT-15', 'Num_Dep_SLDT-10', 'Num_Dep_SLDT-5', 'Num_Dep_SLDT-0', 'Num_Dep_SLDT+5',\
            'Num_Dep_SLDT+10', 'Num_Dep_SLDT+15', 'Num_Dep_SLDT+20', 'Num_Dep_SLDT+25']

features2 = ['Num_Arr_SLDT-30', 'Num_Arr_SLDT-25', 'Num_Arr_SLDT-20', 'Num_Arr_SLDT-15', 'Num_Arr_SLDT-10',\
                'Num_Arr_SLDT-5', 'Num_Arr_SLDT-0', 'Num_Arr_SLDT+5', 'Num_Arr_SLDT+10', 'Num_Arr_SLDT+15',\
                'Num_Arr_SLDT+20', 'Num_Arr_SLDT+25']

# loop through every arrival flight in arrivals df
for i in arrivals.index:
    
    this_SLDT = arrivals['ARR_Flight_SLDT'][i]
    
    minus_30 = this_SLDT - thirty_min
    minus_25 = this_SLDT - twenty5_min
    minus_20 = this_SLDT - twenty_min
    minus_15 = this_SLDT - fifteen_min
    minus_10 = this_SLDT - ten_min
    minus_5 = this_SLDT + five_min
    plus_30 = this_SLDT + thirty_min
    plus_25 = this_SLDT + twenty5_min
    plus_20 = this_SLDT + twenty_min
    plus_15 = this_SLDT + fifteen_min
    plus_10 = this_SLDT + ten_min
    plus_5 = this_SLDT + five_min
    
    time_list = [minus_30, minus_25, minus_20, minus_15, minus_10, minus_5, this_SLDT,\
                 plus_5, plus_10, plus_15, plus_20, plus_25, plus_30]

    for j in range(len(time_list)-1):
        mask_dep = (time_list[j] <= stot) & (stot < time_list[j+1])
        arrivals[features[j]][i] = dep_flight_STOT.loc[mask_dep].shape[0]
        
        mask_arr = (time_list[j] <= sldt) & (sldt < time_list[j+1])
        arrivals[features2[j]][i] = arr_flight_SLDT.loc[mask_arr].shape[0]

# %%
# to remove the arrival flight itself from the number of arrival flights at its SLDT
arrivals['Num_Arr_SLDT-0'] = arrivals['Num_Arr_SLDT-0'] - 1

# %%
arrivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29709 entries, 35 to 570115
# Data columns (total 84 columns):
# Year                               29709 non-null int64
# Quarter                            29709 non-null int64
# Month                              29709 non-null int64
# DayofMonth                         29709 non-null int64
# DayOfWeek                          29709 non-null int64
# FlightDate                         29709 non-null datetime64[ns]
# Reporting_Airline                  29709 non-null object
# DOT_ID_Reporting_Airline           29709 non-null int64
# IATA_CODE_Reporting_Airline        29709 non-null object
# Tail_Number                        29709 non-null object
# Flight_Number_Reporting_Airline    29709 non-null int64
# OriginAirportID                    29709 non-null int64
# OriginAirportSeqID                 29709 non-null int64
# OriginCityMarketID                 29709 non-null int64
# Origin                             29709 non-null object
# OriginCityName                     29709 non-null object
# OriginState                        29709 non-null object
# OriginStateFips                    29709 non-null int64
# OriginStateName                    29709 non-null object
# OriginWac                          29709 non-null int64
# DestAirportID                      29709 non-null int64
# DestAirportSeqID                   29709 non-null int64
# DestCityMarketID                   29709 non-null int64
# Dest                               29709 non-null object
# DestCityName                       29709 non-null object
# DestState                          29709 non-null object
# DestStateFips                      29709 non-null int64
# DestStateName                      29709 non-null object
# DestWac                            29709 non-null int64
# CRSDepTime                         29709 non-null object
# DepTime                            29709 non-null float64
# DepDelay                           29670 non-null float64
# DepDelayMinutes                    29670 non-null float64
# DepDel15                           29670 non-null float64
# DepartureDelayGroups               29670 non-null float64
# DepTimeBlk                         29709 non-null object
# TaxiOut                            29709 non-null float64
# WheelsOff                          29709 non-null float64
# WheelsOn                           29709 non-null float64
# TaxiIn                             29709 non-null float64
# CRSArrTime                         29709 non-null object
# ArrTime                            29709 non-null float64
# ArrDelay                           29695 non-null float64
# ArrDelayMinutes                    29695 non-null float64
# ArrDel15                           29695 non-null float64
# ArrivalDelayGroups                 29695 non-null float64
# ArrTimeBlk                         29709 non-null object
# CRSElapsedTime                     29709 non-null float64
# ActualElapsedTime                  29709 non-null float64
# AirTime                            29709 non-null float64
# Flights                            29709 non-null float64
# Distance                           29709 non-null float64
# DistanceGroup                      29709 non-null int64
# CarrierDelay                       4801 non-null float64
# WeatherDelay                       4801 non-null float64
# NASDelay                           4801 non-null float64
# SecurityDelay                      4801 non-null float64
# LateAircraftDelay                  4801 non-null float64
# ArrivalDate                        29709 non-null datetime64[ns]
# ARR_Flight_SLDT                    29709 non-null datetime64[ns]
# Num_Arr_SLDT-30                    29709 non-null int64
# Num_Arr_SLDT-25                    29709 non-null int64
# Num_Arr_SLDT-20                    29709 non-null int64
# Num_Arr_SLDT-15                    29709 non-null int64
# Num_Arr_SLDT-10                    29709 non-null int64
# Num_Arr_SLDT-5                     29709 non-null int64
# Num_Arr_SLDT-0                     29709 non-null int64
# Num_Arr_SLDT+5                     29709 non-null int64
# Num_Arr_SLDT+10                    29709 non-null int64
# Num_Arr_SLDT+15                    29709 non-null int64
# Num_Arr_SLDT+20                    29709 non-null int64
# Num_Arr_SLDT+25                    29709 non-null int64
# Num_Dep_SLDT-30                    29709 non-null int64
# Num_Dep_SLDT-25                    29709 non-null int64
# Num_Dep_SLDT-20                    29709 non-null int64
# Num_Dep_SLDT-15                    29709 non-null int64
# Num_Dep_SLDT-10                    29709 non-null int64
# Num_Dep_SLDT-5                     29709 non-null int64
# Num_Dep_SLDT-0                     29709 non-null int64
# Num_Dep_SLDT+5                     29709 non-null int64
# Num_Dep_SLDT+10                    29709 non-null int64
# Num_Dep_SLDT+15                    29709 non-null int64
# Num_Dep_SLDT+20                    29709 non-null int64
# Num_Dep_SLDT+25                    29709 non-null int64
# dtypes: datetime64[ns](3), float64(24), int64(42), object(15)
# memory usage: 20.5+ MB
